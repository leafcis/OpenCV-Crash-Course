# %% [markdown]
# <a href="https://colab.research.google.com/github/leafcis/OpenCV-Crash-Course/blob/master/OpenCV_Crash_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# OpenCV Crash Course

# %%
pip install opencv-python

# %%
import cv2
print(cv2.__version__)
# Out:
# 3.4.3

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-ece6b951-e77f-420a-9503-bcf85c6bb7eb" name="files[]" multiple disabled />
#      <output id="result-ece6b951-e77f-420a-9503-bcf85c6bb7eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 28056328_916202945227657_3012599249381125147_n.jpg to 28056328_916202945227657_3012599249381125147_n.jpg

# %%
# !ls
# Out:
# 28056328_916202945227657_3012599249381125147_n.jpg  sample_data

# %% [markdown]
# ## Loading and Displaying and Image

# %%
import imutils
from google.colab.patches import cv2_imshow

# load the input image and show its dimensions, keeping in mind that
# images are represented as a multi-dimensional NumPy array with
# shape no. rows (height) x no. columns (width) x no. channels (depth)
image = cv2.imread("28056328_916202945227657_3012599249381125147_n.jpg")
(h, w, d) = image.shape
print("width={}, height={}, depth={}".format(w, h, d))

# display the image to our screen -- we will need to click the window
# open by OpenCV and press a key on our keyboard to continue execution
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# width=750, height=748, depth=3
# <PIL.Image.Image image mode=RGB size=750x748 at 0x7FA26483EF98>
# -1

# %% [markdown]
# ## Code Review
# #### cv2_imread
# ```python
# image = cv2.imread("28056328_916202945227657_3012599249381125147_n.jpg")
# ```
# To load our specific image, we call `cv2.imread(img loc)``
# By calling this method, we `cv2.image()` assign the result, which is NumPy array
#
#
# #### image.shape
#
# To extract height, width, and depth.

# %% [markdown]
# ## Accessing Individual Pixels
#
# ![](https://www.pyimagesearch.com/wp-content/uploads/2018/06/opencv_tutorial_gradient_rgb.jpg)
#
# ### What is Pixel?
# All images contains pixels. A pixel is like a brick in the building. In other word, Image is made of pixels.

# %% [markdown]
# ### Array Slicing and Cropping

# %% [markdown]
# #### Array Slicing

# %%
roi = image[60:160, 320:420]
cv2_imshow(roi)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA26483ED30>
# -1

# %% [markdown]
# ### Image Resizing
